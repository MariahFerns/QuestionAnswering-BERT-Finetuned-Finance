# %%
# ! pip install datasets

# %%
# Prepare the data dict
train_dataset = (
        {
            "id": "5785a2b9ef927f8b0f8c1254",
            "title": "Citibank_Annual_Report_2023",
            "context": "In the 2023 Annual Report, Citibank reported a net income of $15 billion, reflecting a 10% increase compared to the previous year. The bank also highlighted its efforts in digital transformation, reducing operational costs, and improving customer satisfaction scores.",
            "question": "What was Citibank's net income in 2023?",
            "answers": {
                "text": ["$15 billion"],
                "answer_start": [75]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1255",
            "title": "Citibank_Quarterly_Earnings_Q1",
            "context": "In Q1 2024, Citibank posted revenues of $19 billion, an 8% increase compared to the previous quarter. The earnings report highlighted strong performance in the corporate banking division and an increase in consumer deposits.",
            "question": "What were Citibank's revenues in Q1 2024?",
            "answers": {
                "text": ["$19 billion"],
                "answer_start": [57]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1256",
            "title": "Citibank_Quarterly_Earnings_Q2",
            "context": "Citibank's Q2 2024 earnings showed a net profit of $4 billion, a 5% increase year-over-year. The bank attributed this growth to improved loan performance and cost-cutting measures.",
            "question": "What was Citibank's net profit in Q2 2024?",
            "answers": {
                "text": ["$4 billion"],
                "answer_start": [58]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1257",
            "title": "Citibank_Monthly_Report_April",
            "context": "The April 2024 monthly report indicated that Citibank achieved sales of $6 billion, which was a 2% increase from the previous month. The report emphasized growth in the credit card segment and increased customer engagement through mobile banking platforms.",
            "question": "What were Citibank's sales in April 2024?",
            "answers": {
                "text": ["$6 billion"],
                "answer_start": [69]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1258",
            "title": "Citibank_RoTCE",
            "context": "For the fiscal year 2023, Citibank reported a Return on Tangible Common Equity (RoTCE) of 12%. This metric was bolstered by strong earnings in the investment banking sector and efficient capital management.",
            "question": "What was Citibank's RoTCE in fiscal year 2023?",
            "answers": {
                "text": ["12%"],
                "answer_start": [67]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1259",
            "title": "Citibank_Annual_Report_2022",
            "context": "In the 2022 Annual Report, Citibank announced a total revenue of $75 billion, marking a 6% increase year-on-year. The growth was primarily driven by increased lending activities and higher fee income from wealth management services.",
            "question": "What was Citibank's total revenue in 2022?",
            "answers": {
                "text": ["$75 billion"],
                "answer_start": [65]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1260",
            "title": "Citibank_Quarterly_Earnings_Q3",
            "context": "Citibank's Q3 2023 report showed earnings per share (EPS) of $1.50, which was an improvement from $1.35 in the previous quarter. The bank highlighted significant gains in its trading operations and a reduction in non-performing loans.",
            "question": "What was Citibank's EPS in Q3 2023?",
            "answers": {
                "text": ["$1.50"],
                "answer_start": [59]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1261",
            "title": "Citibank_Monthly_Report_May",
            "context": "The May 2024 monthly report detailed that Citibank's current month sales were $6.2 billion, slightly higher than April's $6 billion. The incremental growth was attributed to a surge in mortgage applications and personal loans.",
            "question": "What were Citibank's sales in May 2024?",
            "answers": {
                "text": ["$6.2 billion"],
                "answer_start": [67]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1262",
            "title": "Citibank_YoY_Growth",
            "context": "In 2023, Citibank experienced a year-on-year growth rate of 7% in its global consumer banking division. This growth was driven by higher spending on credit cards and expansion into new international markets.",
            "question": "What was Citibank's YoY growth rate in global consumer banking in 2023?",
            "answers": {
                "text": ["7%"],
                "answer_start": [42]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1263",
            "title": "Citibank_Quarterly_Earnings_Q4",
            "context": "The Q4 2023 earnings report revealed that Citibank's net interest margin (NIM) was 2.75%, up from 2.65% in Q3 2023. The increase was attributed to rising interest rates and strategic asset reallocation.",
            "question": "What was Citibank's net interest margin in Q4 2023?",
            "answers": {
                "text": ["2.75%"],
                "answer_start": [64]
            }
        },
                {
            "id": "5785a2b9ef927f8b0f8c1254",
            "title": "Citibank_Annual_Report_2023",
            "context": "In the 2023 Annual Report, Citibank reported a net income of $15 billion, reflecting a 10% increase compared to the previous year. The bank also highlighted its efforts in digital transformation, reducing operational costs, and improving customer satisfaction scores.",
            "question": "What was the percentage increase in Citibank's net income in 2023?",
            "answers": {
                "text": ["10%"],
                "answer_start": [98]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1255",
            "title": "Citibank_Quarterly_Earnings_Q1",
            "context": "In Q1 2024, Citibank posted revenues of $19 billion, an 8% increase compared to the previous quarter. The earnings report highlighted strong performance in the corporate banking division and an increase in consumer deposits.",
            "question": "Which division showed strong performance in Citibank's Q1 2024 report?",
            "answers": {
                "text": ["corporate banking"],
                "answer_start": [130]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1256",
            "title": "Citibank_Quarterly_Earnings_Q2",
            "context": "Citibank's Q2 2024 earnings showed a net profit of $4 billion, a 5% increase year-over-year. The bank attributed this growth to improved loan performance and cost-cutting measures.",
            "question": "What factors contributed to Citibank's net profit growth in Q2 2024?",
            "answers": {
                "text": ["improved loan performance and cost-cutting measures"],
                "answer_start": [91]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1257",
            "title": "Citibank_Monthly_Report_April",
            "context": "The April 2024 monthly report indicated that Citibank achieved sales of $6 billion, which was a 2% increase from the previous month. The report emphasized growth in the credit card segment and increased customer engagement through mobile banking platforms.",
            "question": "Which segment showed growth in Citibank's April 2024 report?",
            "answers": {
                "text": ["credit card segment"],
                "answer_start": [108]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1258",
            "title": "Citibank_RoTCE",
            "context": "For the fiscal year 2023, Citibank reported a Return on Tangible Common Equity (RoTCE) of 12%. This metric was bolstered by strong earnings in the investment banking sector and efficient capital management.",
            "question": "What contributed to the rise in Citibank's RoTCE in 2023?",
            "answers": {
                "text": ["strong earnings in the investment banking sector and efficient capital management"],
                "answer_start": [83]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1259",
            "title": "Citibank_Annual_Report_2022",
            "context": "In the 2022 Annual Report, Citibank announced a total revenue of $75 billion, marking a 6% increase year-on-year. The growth was primarily driven by increased lending activities and higher fee income from wealth management services.",
            "question": "hat drove the growth in Citibank's total revenue in 2022?",
            "answers": {
                "text": ["increased lending activities and higher fee income from wealth management services"],
                "answer_start": [107]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1260",
            "title": "Citibank_Quarterly_Earnings_Q3",
            "context": "Citibank's Q3 2023 report showed earnings per share (EPS) of $1.50, which was an improvement from $1.35 in the previous quarter. The bank highlighted significant gains in its trading operations and a reduction in non-performing loans.",
            "question": "What did Citibank highlight as significant gains in its Q3 2023 report?",
            "answers": {
                "text": ["gains in its trading operations and a reduction in non-performing loans"],
                "answer_start": [97]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1261",
            "title": "Citibank_Monthly_Report_May",
            "context": "The May 2024 monthly report detailed that Citibank's current month sales were $6.2 billion, slightly higher than April's $6 billion. The incremental growth was attributed to a surge in mortgage applications and personal loans.",
            "question": "What factors led to the incremental growth in Citibank's sales in May 2024?",
            "answers": {
                "text": ["a surge in mortgage applications and personal loans"],
                "answer_start": [100]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1262",
            "title": "Citibank_YoY_Growth",
            "context": "In 2023, Citibank experienced a year-on-year growth rate of 7% in its global consumer banking division. This growth was driven by higher spending on credit cards and expansion into new international markets.",
            "question": "What was the percentage increase in Citibank's YoY growth rate in 2023?",
            "answers": {
                "text": ["7%"],
                "answer_start": [42]
            }
        },
        {
            "id": "5785a2b9ef927f8b0f8c1263",
            "title": "Citibank_Quarterly_Earnings_Q4",
            "context": "The Q4 2023 earnings report revealed that Citibank's net interest margin (NIM) was 2.75%, up from 2.65% in Q3 2023. The increase was attributed to rising interest rates and strategic asset reallocation.",
            "question": "What was the increase in Citibank's net interest margin from Q3 to Q4 2023?",
            "answers": {
                "text": ["0.1%"],
                "answer_start": [61]
            }
        },
        {
        "id": "5785a2b9ef927f8b0f8c1264",
        "title": "Citibank_Annual_Report_2023",
        "context": "In 2023, Citibank's Return on Assets (ROA) was reported at 0.95%, an improvement from the previous year's 0.85%. The increase was driven by higher net income and efficient asset management.",
        "question": "What was Citibank's Return on Assets (ROA) in 2023?",
        "answers": {
            "text": ["0.95%"],
            "answer_start": [52]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1265",
        "title": "Citibank_Quarterly_Earnings_Q2",
        "context": "During Q2 2024, Citibank's non-performing loans (NPL) ratio improved to 1.2%, down from 1.4% in Q1 2024. The improvement was attributed to better credit risk management and economic recovery.",
        "question": "What was Citibank's NPL ratio in Q2 2024?",
        "answers": {
            "text": ["1.2%"],
            "answer_start": [54]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1266",
        "title": "Citibank_Monthly_Report_June",
        "context": "The June 2024 monthly report highlighted that Citibank's customer deposits reached $400 billion, a 3% increase from May 2024. The growth was driven by competitive interest rates and new savings products.",
        "question": "What were Citibank's customer deposits in June 2024?",
        "answers": {
            "text": ["$400 billion"],
            "answer_start": [69]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1267",
        "title": "Citibank_Annual_Report_2022",
        "context": "In the 2022 Annual Report, Citibank reported an efficiency ratio of 55%, reflecting the bank's efforts to control costs and improve operational efficiency.",
        "question": "What was Citibank's efficiency ratio in 2022?",
        "answers": {
            "text": ["55%"],
            "answer_start": [66]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1268",
        "title": "Citibank_Quarterly_Earnings_Q3",
        "context": "Citibank's Q3 2024 earnings report revealed a total loan portfolio of $700 billion, a 4% increase from Q2 2024. The growth was mainly in the commercial lending sector.",
        "question": "What was the size of Citibank's loan portfolio in Q3 2024?",
        "answers": {
            "text": ["$700 billion"],
            "answer_start": [67]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1269",
        "title": "Citibank_Monthly_Report_July",
        "context": "In July 2024, Citibank reported an increase in credit card spending to $12 billion, a 5% rise from the previous month, driven by summer travel and promotional offers.",
        "question": "What was Citibank's credit card spending in July 2024?",
        "answers": {
            "text": ["$12 billion"],
            "answer_start": [63]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1270",
        "title": "Citibank_Annual_Report_2023",
        "context": "The 2023 Annual Report noted that Citibank's Tier 1 Capital Ratio was 13.5%, reflecting a strong capital position and regulatory compliance.",
        "question": "What was Citibank's Tier 1 Capital Ratio in 2023?",
        "answers": {
            "text": ["13.5%"],
            "answer_start": [56]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1271",
        "title": "Citibank_Quarterly_Earnings_Q4",
        "context": "In Q4 2023, Citibank's revenue from investment banking services reached $3 billion, an increase of 10% from Q3 2023, due to several high-profile deals.",
        "question": "What was Citibank's revenue from investment banking services in Q4 2023?",
        "answers": {
            "text": ["$3 billion"],
            "answer_start": [68]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1272",
        "title": "Citibank_Monthly_Report_August",
        "context": "The August 2024 monthly report showed that Citibank's mortgage lending increased to $25 billion, a 4% rise from July 2024, driven by lower interest rates.",
        "question": "What was Citibank's mortgage lending in August 2024?",
        "answers": {
            "text": ["$25 billion"],
            "answer_start": [66]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1273",
        "title": "Citibank_Annual_Report_2023",
        "context": "In 2023, Citibank's digital banking users grew to 30 million, representing a 15% increase from 2022, reflecting the bank's investment in digital services.",
        "question": "How many digital banking users did Citibank have in 2023?",
        "answers": {
            "text": ["30 million"],
            "answer_start": [50]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1274",
        "title": "Citibank_Quarterly_Earnings_Q1",
        "context": "During Q1 2024, Citibank's non-interest income was $5 billion, which remained stable compared to Q4 2023, with strong performance in wealth management.",
        "question": "What was Citibank's non-interest income in Q1 2024?",
        "answers": {
            "text": ["$5 billion"],
            "answer_start": [55]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1275",
        "title": "Citibank_Monthly_Report_September",
        "context": "In September 2024, Citibank's personal loan portfolio reached $50 billion, a slight increase from $48 billion in August 2024, driven by promotional loan offers.",
        "question": "What was Citibank's personal loan portfolio in September 2024?",
        "answers": {
            "text": ["$50 billion"],
            "answer_start": [67]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1276",
        "title": "Citibank_Annual_Report_2023",
        "context": "According to the 2023 Annual Report, Citibank's operating expenses were $30 billion, reflecting cost control measures and operational efficiencies.",
        "question": "What were Citibank's operating expenses in 2023?",
        "answers": {
            "text": ["$30 billion"],
            "answer_start": [58]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1277",
        "title": "Citibank_Quarterly_Earnings_Q2",
        "context": "In Q2 2024, Citibank's total assets amounted to $2 trillion, showing a 3% increase from Q1 2024, supported by growth in both consumer and corporate banking.",
        "question": "What were Citibank's total assets in Q2 2024?",
        "answers": {
            "text": ["$2 trillion"],
            "answer_start": [52]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1278",
        "title": "Citibank_Monthly_Report_October",
        "context": "The October 2024 monthly report noted that Citibank's net income was $1.2 billion, down 2% from September 2024, primarily due to higher loan loss provisions.",
        "question": "What was Citibank's net income in October 2024?",
        "answers": {
            "text": ["$1.2 billion"],
            "answer_start": [56]
        }
    },
        {
        "id": "5785a2b9ef927f8b0f8c1280",
        "title": "Citibank_Annual_Report_2023",
        "context": "In 2023, Citibank's book value per share was reported at $80, reflecting strong equity growth and retained earnings.",
        "question": "What was Citibank's book value per share in 2023?",
        "answers": {
            "text": ["$80"],
            "answer_start": [45]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1281",
        "title": "Citibank_Quarterly_Earnings_Q4",
        "context": "In Q4 2023, Citibank's net interest margin (NIM) increased to 2.7%, up from 2.5% in Q3 2023, due to higher interest rates on loans.",
        "question": "What was Citibank's net interest margin in Q4 2023?",
        "answers": {
            "text": ["2.7%"],
            "answer_start": [53]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1282",
        "title": "Citibank_Monthly_Report_November",
        "context": "The November 2024 monthly report indicated that Citibank's total revenue for the month was $5.5 billion, a 3% increase from October 2024.",
        "question": "What was Citibank's total revenue in November 2024?",
        "answers": {
            "text": ["$5.5 billion"],
            "answer_start": [60]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1283",
        "title": "Citibank_Annual_Report_2023",
        "context": "Citibank's 2023 Annual Report highlighted a dividend payout ratio of 30%, reflecting the bank's commitment to returning value to shareholders.",
        "question": "What was Citibank's dividend payout ratio in 2023?",
        "answers": {
            "text": ["30%"],
            "answer_start": [68]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1284",
        "title": "Citibank_Quarterly_Earnings_Q1",
        "context": "During Q1 2024, Citibank's equity capital increased to $250 billion, a 5% rise from Q4 2023, driven by retained earnings and capital injections.",
        "question": "What was Citibank's equity capital in Q1 2024?",
        "answers": {
            "text": ["$250 billion"],
            "answer_start": [54]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1285",
        "title": "Citibank_Monthly_Report_December",
        "context": "In December 2024, Citibank's fee income was reported at $1.8 billion, a 4% increase from November 2024, due to higher transaction volumes.",
        "question": "What was Citibank's fee income in December 2024?",
        "answers": {
            "text": ["$1.8 billion"],
            "answer_start": [52]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1286",
        "title": "Citibank_Annual_Report_2023",
        "context": "The 2023 Annual Report disclosed that Citibank's total equity was $300 billion, reflecting a strong capital position and shareholder equity.",
        "question": "What was Citibank's total equity in 2023?",
        "answers": {
            "text": ["$300 billion"],
            "answer_start": [54]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1287",
        "title": "Citibank_Quarterly_Earnings_Q2",
        "context": "In Q2 2024, Citibank's consumer banking revenue reached $10 billion, a 6% increase from Q1 2024, driven by higher lending and deposit volumes.",
        "question": "What was Citibank's consumer banking revenue in Q2 2024?",
        "answers": {
            "text": ["$10 billion"],
            "answer_start": [58]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1288",
        "title": "Citibank_Monthly_Report_January",
        "context": "The January 2024 monthly report showed that Citibank's trading income was $3.2 billion, a 5% increase from December 2023, due to favorable market conditions.",
        "question": "What was Citibank's trading income in January 2024?",
        "answers": {
            "text": ["$3.2 billion"],
            "answer_start": [55]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1289",
        "title": "Citibank_Annual_Report_2023",
        "context": "Citibank's 2023 Annual Report noted that the bank's cost of funds was 1.2%, reflecting efficient funding and capital management strategies.",
        "question": "What was Citibank's cost of funds in 2023?",
        "answers": {
            "text": ["1.2%"],
            "answer_start": [64]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1290",
        "title": "Citibank_Quarterly_Earnings_Q3",
        "context": "In Q3 2024, Citibank's net profit margin was 20%, up from 18% in Q2 2024, due to increased revenue and controlled expenses.",
        "question": "What was Citibank's net profit margin in Q3 2024?",
        "answers": {
            "text": ["20%"],
            "answer_start": [49]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1291",
        "title": "Citibank_Monthly_Report_February",
        "context": "In February 2024, Citibank's corporate lending portfolio grew to $350 billion, a 2% increase from January 2024, driven by new loan originations.",
        "question": "What was Citibank's corporate lending portfolio in February 2024?",
        "answers": {
            "text": ["$350 billion"],
            "answer_start": [58]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1292",
        "title": "Citibank_Annual_Report_2023",
        "context": "The 2023 Annual Report indicated that Citibank's cost-to-income ratio was 45%, reflecting effective cost management and operational efficiency.",
        "question": "What was Citibank's cost-to-income ratio in 2023?",
        "answers": {
            "text": ["45%"],
            "answer_start": [54]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1293",
        "title": "Citibank_Quarterly_Earnings_Q4",
        "context": "During Q4 2023, Citibank's total deposits were reported at $1.5 trillion, an increase of 3% from Q3 2023, driven by higher savings and checking account balances.",
        "question": "What were Citibank's total deposits in Q4 2023?",
        "answers": {
            "text": ["$1.5 trillion"],
            "answer_start": [50]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1294",
        "title": "Citibank_Monthly_Report_March",
        "context": "In March 2024, Citibank's net interest income was $4 billion, a 2% increase from February 2024, due to higher loan balances and interest rates.",
        "question": "What was Citibank's net interest income in March 2024?",
        "answers": {
            "text": ["$4 billion"],
            "answer_start": [54]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1300",
        "title": "Citibank_Annual_Report_2023",
        "context": "In 2023, Citibank focused on expanding its digital banking platform, leading to a significant increase in user engagement and satisfaction.",
        "question": "What did Citibank focus on in 2023?",
        "answers": {
            "text": ["expanding its digital banking platform"],
            "answer_start": [30]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1301",
        "title": "Citibank_Quarterly_Earnings_Q4",
        "context": "During Q4 2023, Citibank introduced a new range of credit card products, which were well-received by customers and contributed to higher fee income.",
        "question": "What did Citibank introduce in Q4 2023?",
        "answers": {
            "text": ["a new range of credit card products"],
            "answer_start": [37]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1302",
        "title": "Citibank_Monthly_Report_January",
        "context": "In January 2024, Citibank launched a new mobile banking app that offers enhanced security features and a more user-friendly interface.",
        "question": "What did Citibank launch in January 2024?",
        "answers": {
            "text": ["a new mobile banking app"],
            "answer_start": [27]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1303",
        "title": "Citibank_Annual_Report_2022",
        "context": "The 2022 Annual Report highlighted Citibank's commitment to sustainability, including investments in green energy projects and reducing its carbon footprint.",
        "question": "What commitment did Citibank highlight in its 2022 Annual Report?",
        "answers": {
            "text": ["commitment to sustainability"],
            "answer_start": [44]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1304",
        "title": "Citibank_Quarterly_Earnings_Q1",
        "context": "During Q1 2024, Citibank expanded its presence in the Asia-Pacific region, opening several new branches to better serve the growing market.",
        "question": "What did Citibank do in the Asia-Pacific region during Q1 2024?",
        "answers": {
            "text": ["expanded its presence"],
            "answer_start": [30]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1305",
        "title": "Citibank_Monthly_Report_February",
        "context": "In February 2024, Citibank received an award for its innovative customer service initiatives, which have greatly improved client satisfaction.",
        "question": "What did Citibank receive in February 2024?",
        "answers": {
            "text": ["an award for its innovative customer service initiatives"],
            "answer_start": [27]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1306",
        "title": "Citibank_Annual_Report_2023",
        "context": "The 2023 Annual Report detailed Citibank's efforts to enhance cybersecurity measures, including the implementation of advanced threat detection systems.",
        "question": "What efforts did Citibank detail in its 2023 Annual Report?",
        "answers": {
            "text": ["efforts to enhance cybersecurity measures"],
            "answer_start": [37]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1307",
        "title": "Citibank_Quarterly_Earnings_Q3",
        "context": "In Q3 2024, Citibank partnered with several fintech companies to develop innovative financial products and services.",
        "question": "Who did Citibank partner with in Q3 2024?",
        "answers": {
            "text": ["several fintech companies"],
            "answer_start": [30]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1308",
        "title": "Citibank_Monthly_Report_March",
        "context": "In March 2024, Citibank hosted a global economic forum to discuss emerging market trends and investment opportunities with industry leaders.",
        "question": "What event did Citibank host in March 2024?",
        "answers": {
            "text": ["a global economic forum"],
            "answer_start": [27]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1309",
        "title": "Citibank_Annual_Report_2023",
        "context": "According to the 2023 Annual Report, Citibank focused on enhancing customer experience through digital transformation and personalized services.",
        "question": "What did Citibank focus on according to the 2023 Annual Report?",
        "answers": {
            "text": ["enhancing customer experience through digital transformation and personalized services"],
            "answer_start": [42]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1310",
        "title": "Citibank_Quarterly_Earnings_Q2",
        "context": "In Q2 2024, Citibank's strategic focus was on expanding its wealth management division, offering new products to high-net-worth individuals.",
        "question": "What was Citibank's strategic focus in Q2 2024?",
        "answers": {
            "text": ["expanding its wealth management division"],
            "answer_start": [37]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1311",
        "title": "Citibank_Monthly_Report_April",
        "context": "The April 2024 monthly report emphasized Citibank's efforts to support small businesses, including offering low-interest loans and advisory services.",
        "question": "What did Citibank emphasize in its April 2024 report?",
        "answers": {
            "text": ["efforts to support small businesses"],
            "answer_start": [52]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1312",
        "title": "Citibank_Annual_Report_2023",
        "context": "The 2023 Annual Report highlighted Citibank's global expansion strategy, focusing on emerging markets and developing economies.",
        "question": "What strategy did Citibank highlight in its 2023 Annual Report?",
        "answers": {
            "text": ["global expansion strategy"],
            "answer_start": [44]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1313",
        "title": "Citibank_Quarterly_Earnings_Q4",
        "context": "In Q4 2023, Citibank saw significant growth in its commercial banking sector, driven by an increase in corporate loans and deposits.",
        "question": "Where did Citibank see significant growth in Q4 2023?",
        "answers": {
            "text": ["its commercial banking sector"],
            "answer_start": [34]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1314",
        "title": "Citibank_Monthly_Report_May",
        "context": "In May 2024, Citibank announced a new sustainability initiative aimed at reducing its carbon footprint and promoting green energy solutions.",
        "question": "What did Citibank announce in May 2024?",
        "answers": {
            "text": ["a new sustainability initiative"],
            "answer_start": [27]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1400",
        "title": "Citibank_Quarterly_Earnings_Q1",
        "context": "In Q1 2024, Citibank's share price experienced an upward trend due to strong financial performance and positive market sentiment.",
        "question": "What caused Citibank's share price to increase in Q1 2024?",
        "answers": {
            "text": ["strong financial performance and positive market sentiment"],
            "answer_start": [74]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1401",
        "title": "Citibank_Monthly_Report_January",
        "context": "In January 2024, Citibank's share price saw a slight decline following an announcement of increased regulatory scrutiny.",
        "question": "What caused Citibank's share price to decline in January 2024?",
        "answers": {
            "text": ["announcement of increased regulatory scrutiny"],
            "answer_start": [67]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1402",
        "title": "Citibank_Annual_Report_2023",
        "context": "The 2023 Annual Report noted that Citibank's share price was bolstered by its successful cost-cutting measures and improved operational efficiency.",
        "question": "What factors bolstered Citibank's share price according to the 2023 Annual Report?",
        "answers": {
            "text": ["successful cost-cutting measures and improved operational efficiency"],
            "answer_start": [69]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1403",
        "title": "Citibank_Quarterly_Earnings_Q2",
        "context": "During Q2 2024, Citibank's share price remained stable despite market volatility, thanks to its robust risk management practices.",
        "question": "Why did Citibank's share price remain stable in Q2 2024?",
        "answers": {
            "text": ["robust risk management practices"],
            "answer_start": [87]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1404",
        "title": "Citibank_Monthly_Report_February",
        "context": "In February 2024, Citibank's share price surged following the release of better-than-expected quarterly earnings.",
        "question": "What caused Citibank's share price to surge in February 2024?",
        "answers": {
            "text": ["release of better-than-expected quarterly earnings"],
            "answer_start": [66]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1405",
        "title": "Citibank_Annual_Report_2023",
        "context": "According to the 2023 Annual Report, Citibank's share price benefited from strategic acquisitions that expanded its market reach.",
        "question": "What benefited Citibank's share price according to the 2023 Annual Report?",
        "answers": {
            "text": ["strategic acquisitions that expanded its market reach"],
            "answer_start": [73]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1406",
        "title": "Citibank_Quarterly_Earnings_Q3",
        "context": "In Q3 2024, Citibank's share price was negatively impacted by geopolitical tensions that led to broader market declines.",
        "question": "What negatively impacted Citibank's share price in Q3 2024?",
        "answers": {
            "text": ["geopolitical tensions that led to broader market declines"],
            "answer_start": [59]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1407",
        "title": "Citibank_Monthly_Report_March",
        "context": "In March 2024, Citibank's share price climbed after the bank announced a new strategic partnership with a leading tech company.",
        "question": "What caused Citibank's share price to climb in March 2024?",
        "answers": {
            "text": ["announcement of a new strategic partnership with a leading tech company"],
            "answer_start": [66]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1408",
        "title": "Citibank_Annual_Report_2023",
        "context": "The 2023 Annual Report indicated that Citibank's share price was supported by its strong capital position and dividend payouts.",
        "question": "What supported Citibank's share price according to the 2023 Annual Report?",
        "answers": {
            "text": ["strong capital position and dividend payouts"],
            "answer_start": [68]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1409",
        "title": "Citibank_Quarterly_Earnings_Q4",
        "context": "During Q4 2023, Citibank's share price saw a positive impact from the launch of a new digital banking platform.",
        "question": "What had a positive impact on Citibank's share price in Q4 2023?",
        "answers": {
            "text": ["launch of a new digital banking platform"],
            "answer_start": [64]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1410",
        "title": "Citibank_Monthly_Report_April",
        "context": "In April 2024, Citibank's share price was affected by global economic uncertainty, causing investors to be cautious.",
        "question": "What affected Citibank's share price in April 2024?",
        "answers": {
            "text": ["global economic uncertainty"],
            "answer_start": [39]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1411",
        "title": "Citibank_Annual_Report_2023",
        "context": "The 2023 Annual Report emphasized that Citibank's share price was influenced by its innovative financial products and services.",
        "question": "What influenced Citibank's share price according to the 2023 Annual Report?",
        "answers": {
            "text": ["its innovative financial products and services"],
            "answer_start": [68]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1412",
        "title": "Citibank_Quarterly_Earnings_Q1",
        "context": "In Q1 2024, Citibank's share price was bolstered by investor confidence following a series of positive earnings reports.",
        "question": "What bolstered Citibank's share price in Q1 2024?",
        "answers": {
            "text": ["investor confidence following a series of positive earnings reports"],
            "answer_start": [52]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1413",
        "title": "Citibank_Monthly_Report_May",
        "context": "In May 2024, Citibank's share price increased due to the announcement of a major new investment in renewable energy projects.",
        "question": "What caused Citibank's share price to increase in May 2024?",
        "answers": {
            "text": ["announcement of a major new investment in renewable energy projects"],
            "answer_start": [55]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1414",
        "title": "Citibank_Annual_Report_2023",
        "context": "The 2023 Annual Report noted that Citibank's share price was stabilized by its effective risk management and diversified portfolio.",
        "question": "What stabilized Citibank's share price according to the 2023 Annual Report?",
        "answers": {
            "text": ["effective risk management and diversified portfolio"],
            "answer_start": [65]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1415",
        "title": "Citibank_Quarterly_Earnings_Q2",
        "context": "In Q2 2024, Citibank's share price increased by 5% following the announcement of a 20% increase in net income compared to the previous quarter.",
        "question": "By how much did Citibank's share price increase in Q2 2024?",
        "answers": {
            "text": ["5%"],
            "answer_start": [47]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1416",
        "title": "Citibank_Monthly_Report_June",
        "context": "In June 2024, Citibank's share price rose by $3.50 per share due to strong performance in its investment banking division.",
        "question": "By how much did Citibank's share price rise in June 2024?",
        "answers": {
            "text": ["$3.50 per share"],
            "answer_start": [47]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1417",
        "title": "Citibank_Annual_Report_2023",
        "context": "According to the 2023 Annual Report, Citibank's share price was positively influenced by a 15% increase in its dividend payout.",
        "question": "By how much did Citibank increase its dividend payout according to the 2023 Annual Report?",
        "answers": {
            "text": ["15%"],
            "answer_start": [87]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1418",
        "title": "Citibank_Quarterly_Earnings_Q3",
        "context": "During Q3 2024, Citibank's share price declined by 8% due to a 12% decrease in its trading revenue.",
        "question": "By how much did Citibank's share price decline in Q3 2024?",
        "answers": {
            "text": ["8%"],
            "answer_start": [48]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1419",
        "title": "Citibank_Monthly_Report_July",
        "context": "In July 2024, Citibank's share price increased by 6% after the company announced a $1 billion stock buyback program.",
        "question": "By how much did Citibank's share price increase in July 2024?",
        "answers": {
            "text": ["6%"],
            "answer_start": [48]
        }
    },
    {
        "id": "5785a2b9ef927f8b0f8c1420",
        "title": "Citibank_Annual_Report_2023",
        "context": "The 2023 Annual Report highlighted that Citibank's share price was supported by a 10% year-over-year increase in earnings per share.",
        "question": "By how much did Citibank's earnings per share increase year-over-year according to the 2023 Annual Report?",
        "answers": {
            "text": ["10%"],
            "answer_start": [79]
        }
    }
)

# %%
# generate 15 more samples for citibank in the same format as above. answers can include multiple relevant answers in a list with corresponding list of indices in aswer_start
val_dataset = (
    {
    "id": "574f87ebaf324b1000890b00",
    "title": "Citibank - Monthly Sales",
    "context": "Citibank's monthly sales report for May 2024 indicates a strong performance in the Consumer Banking segment, driven by growth in credit card transactions and mortgage originations. However, the Institutional Banking segment saw a slight decline in revenue compared to April 2024, due to lower trading activity.",
    "question": "What was the performance of Citibank's Consumer Banking segment in May 2024?",
    "answers": {"text": ["strong performance...growth in credit card transactions and mortgage originations"], "answer_start": [8]}
  },
  {
    "id": "574f87ebaf324b1000890b01",
    "title": "Citibank - Quarterly Earnings",
    "context": "Citibank reported Q1 2024 earnings per share (EPS) of $2.15, exceeding analyst expectations of $2.00. The bank's net income increased by 10% year-over-year, driven by higher net interest margin and growth in wealth management fees.",
    "question": "How did Citibank's Q1 2024 EPS compare to analyst expectations?",
    "answers": {"text": ["exceeding analyst expectations of $2.00"], "answer_start": [58]}
  },
  {
    "id": "574f87ebaf324b1000890b02",
    "title": "Citibank - Year-on-Year Growth",
    "context": "Citibank's total revenue for the first half of 2024 grew by 5% compared to the same period in 2023. This growth was primarily due to an increase in loan originations and higher trading volumes.",
    "question": "What was Citibank's year-on-year revenue growth for the first half of 2024?",
    "answers": {"text": ["5%"], "answer_start": [48]}
  },
  {
    "id": "574f87ebaf324b1000890b03",
    "title": "Citibank - Return on Tangible Common Equity (RoTCE)",
    "context": "Citibank's RoTCE ratio for Q1 2024 was 13.5%, exceeding the company's target of 12%. This strong performance reflects the bank's efficient use of capital and its focus on generating shareholder value.",
    "question": "What was Citibank's RoTCE ratio for Q1 2024?",
    "answers": {"text": ["13.5%"], "answer_start": [43]}
  },
  {
    "id": "574f87ebaf324b1000890b04",
    "title": "Citibank - Credit Quality",
    "context": "Citibank's non-performing loan (NPL) ratio remained stable at 1% in Q1 2024. This indicates that the bank is effectively managing its credit risk and maintaining a healthy loan portfolio.",
    "question": "What was Citibank's non-performing loan ratio in Q1 2024?",
    "answers": {"text": ["1%"], "answer_start": [48]}
  },
  {
    "id": "574f87ebaf324b1000890b05",
    "title": "Citibank - CEO Message",
    "context": "In his message to shareholders, Citibank's CEO highlighted the bank's commitment to digital innovation and its focus on expanding its global wealth management business. He also expressed confidence in the bank's ability to achieve sustainable long-term growth.",
    "question": "What are Citibank's key strategic priorities according to the CEO?",
    "answers": {"text": ["digital innovation...expanding its global wealth management business"], "answer_start": [33]}
  },

)

# %%
train_dataset[0]
# Out:
# {'id': '5785a2b9ef927f8b0f8c1254',
#  'title': 'Citibank_Annual_Report_2023',
#  'context': 'In the 2023 Annual Report, Citibank reported a net income of $15 billion, reflecting a 10% increase compared to the previous year. The bank also highlighted its efforts in digital transformation, reducing operational costs, and improving customer satisfaction scores.',
#  'question': "What was Citibank's net income in 2023?",
#  'answers': {'text': ['$15 billion'], 'answer_start': [75]}}

# %%
val_dataset[0]
# Out:
# {'id': '574f87ebaf324b1000890b00',
#  'title': 'Citibank - Monthly Sales',
#  'context': "Citibank's monthly sales report for May 2024 indicates a strong performance in the Consumer Banking segment, driven by growth in credit card transactions and mortgage originations. However, the Institutional Banking segment saw a slight decline in revenue compared to April 2024, due to lower trading activity.",
#  'question': "What was the performance of Citibank's Consumer Banking segment in May 2024?",
#  'answers': {'text': ['strong performance...growth in credit card transactions and mortgage originations'],
#   'answer_start': [8]}}

# %%
# Save the dataset to a JSON file
import json

with open('fpa_financial_qa_train.json', 'w') as f:
    json.dump(train_dataset, f, indent=4)

with open('fpa_financial_qa_val.json', 'w') as f:
    json.dump(val_dataset, f, indent=4)

# %%
# Load the json file as a DatasetDict

from datasets import load_dataset

train_dataset = load_dataset("json", data_files="fpa_financial_qa_train.json")
val_dataset = load_dataset("json", data_files="fpa_financial_qa_val.json")
train_dataset, val_dataset
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# (DatasetDict({
#      train: Dataset({
#          features: ['id', 'title', 'answers', 'question', 'context'],
#          num_rows: 86
#      })
#  }),
#  DatasetDict({
#      train: Dataset({
#          features: ['id', 'title', 'answers', 'question', 'context'],
#          num_rows: 6
#      })
#  }))

# %%
# Order of features is shuffled. Connverting to a pandas df to rearrange columns

train_dataset.set_format('pandas')
train_dataset_df = train_dataset['train'][:]

val_dataset.set_format('pandas')
val_dataset_df = val_dataset['train'][:]

type(train_dataset_df), type(val_dataset_df)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
# Rearranging order of columns
train_dataset_df = train_dataset_df[['id','title', 'context', 'question','answers']]
val_dataset_df = val_dataset_df[['id','title', 'context', 'question','answers']]

# Converting pandas df back to DatasetDict
train_dataset = Dataset.from_pandas(train_dataset_df)
val_dataset   = Dataset.from_pandas(val_dataset_df)

train_dataset,val_dataset
# Out:
# (Dataset({
#      features: ['id', 'title', 'context', 'question', 'answers'],
#      num_rows: 86
#  }),
#  Dataset({
#      features: ['id', 'title', 'context', 'question', 'answers'],
#      num_rows: 6
#  }))

# %% [markdown]
# ## Upload dataset to Huggingface Hub

# %%
# Login to huggingface

from huggingface_hub import notebook_login
notebook_login()

# %%
# Save the dataset to Hugging Face Hub

train_dataset.push_to_hub("Mariah64/fpa_financial_qa_train")
val_dataset.push_to_hub("Mariah64/fpa_financial_qa_val")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/Mariah64/fpa_financial_qa_val/commit/4f4f4322842e78b62ec2ea3e53d529231f93e936', commit_message='Upload dataset', commit_description='', oid='4f4f4322842e78b62ec2ea3e53d529231f93e936', pr_url=None, pr_revision=None, pr_num=None)

# %%
# Download the dataset locally

mari_train = load_dataset("Mariah64/fpa_financial_qa_train")
mari_val = load_dataset("Mariah64/fpa_financial_qa_val")
# Out:
# ...
# Generating train split:   0%|          | 0/6 [00:00<?, ? examples/s]

# %%
# View the dataset

mari_train, mari_val
# Out:
# (DatasetDict({
#      train: Dataset({
#          features: ['id', 'title', 'context', 'question', 'answers'],
#          num_rows: 86
#      })
#  }),
#  DatasetDict({
#      train: Dataset({
#          features: ['id', 'title', 'context', 'question', 'answers'],
#          num_rows: 6
#      })
#  }))

# %%
mari['train'][0]
# Out:
# {'id': '5785a2b9ef927f8b0f8c1254',
#  'title': 'Citibank_Annual_Report_2023',
#  'context': 'In the 2023 Annual Report, Citibank reported a net income of $15 billion, reflecting a 10% increase compared to the previous year. The bank also highlighted its efforts in digital transformation, reducing operational costs, and improving customer satisfaction scores.',
#  'question': "What was Citibank's net income in 2023?",
#  'answers': {'answer_start': [75], 'text': ['$15 billion']}}
